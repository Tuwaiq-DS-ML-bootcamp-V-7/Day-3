# %% [markdown]
# # Python_Lab_1.2

# %% [markdown]
# ### Task 1:
# 1. Create a tuple with the following details:
#     - Your favorite movie (string)
#     - The year it was released (integer)
#     - Its rating out of 10 (float)
#     - Whether you have watched it (boolean)
# 2. Print the detailes

# %%
# Q1
favorite_movie= ("The Dark Knight", 2008, 9.0, True)

# Q2
print("Movie:", favorite_movie[0], "Year:", favorite_movie[1],
      "Rating:", favorite_movie[2], "Watched?:", favorite_movie[3])
# Out:
# Movie: The Dark Knight Year: 2008 Rating: 9.0 Watched?: True

# %% [markdown]
# ### Task 2:
# 1. Create a set of 5 favorite colors.
# 2. Print all the colors

# %%
# Q1
favorite_colors = {"Blue", "Pink", "black", "Yellow", "Purple"}

# Q2
for color in favorite_colors:
    print(color)
# Out:
# Blue
# Yellow
# Purple
# Pink
# black

# %% [markdown]
# ### Task 3:
# 1. Create a dictionary to store information about 3 friends (name as key and a tuple with age and favorite hobby as value).
# 2. Print the details of all friends.

# %%
# Q1
friends = {
    "Samah": (27, "Reading"),
    "Yara": (25, "Painting"),
    "Lara": (21, "Playing video games")}

# Q2
for name, detail in friends.items():
    age, hobby = detail
    print(f"Name:{name}, Age:{age}, Hobby:{hobby}")
# Out:
# Name:Samah, Age:27, Hobby:Reading
# Name:Yara, Age:25, Hobby:Painting
# Name:Lara, Age:21, Hobby:Playing video games

# %% [markdown]
# ### Task 4:
# 1. Check if you have watched the movie and print an appropriate message.
# 1. Check if a specific color is in your favorite colors set and print its availability status.

# %%
# Q1
if favorite_movie[3]: 
    print("You have watched the movie.")
else:
    print("You have not watched the movie.")

# Q2
check = "Red"

if check in favorite_colors:
    print(f"{check} is in your favorite colors.")
else:
    print(f"{check} is not in your favorite colors.")
# Out:
# You have watched the movie.
# Red is not in your favorite colors.
